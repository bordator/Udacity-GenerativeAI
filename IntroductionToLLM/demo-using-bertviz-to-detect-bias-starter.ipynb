# %% [markdown]
# # Demo: Using BertViz To Detect Bias
#
# Auto-regressive models trained on data created by human beings (e.g., data from the internet) will exhibit many of the same biases of those human beings. Thus, being able to visualize what's happening inside transformers is important to understanding this bias. One tool for visualizing attention is [BertViz](https://github.com/jessevig/bertviz?tab=readme-ov-file#self-attention-models-bert-gpt-2-etc).

# %% [markdown]
# ## The doctor asked the nurse...
#
# Two sentences are run through the auto-regressive GPT2 model:
#
# * "The doctor asked the nurse a question. She"
# * "The doctor asked the nurse a question. He"
#
# We notice that the attention head #10 in the 5th layer shows the pronouns "She" and "He" attending to the words "nurse" and "doctor", respectively.

# %%
# !!pip install bertviz
# Out:
# ['Collecting bertviz',
#  '  Downloading bertviz-1.4.0-py3-none-any.whl.metadata (19 kB)',
#  'Requirement already satisfied: transformers>=2.0 in /opt/anaconda3/envs/udagen/lib/python3.11/site-packages (from bertviz) (4.37.2)',
#  'Requirement already satisfied: torch>=1.0 in /opt/anaconda3/envs/udagen/lib/python3.11/site-packages (from bertviz) (2.4.0.dev20240517)',
#  'Requirement already satisfied: tqdm in /opt/anaconda3/envs/udagen/lib/python3.11/site-packages (from bertviz) (4.66.2)',
#  'Collecting boto3 (from bertviz)',
#  '  Downloading boto3-1.34.117-py3-none-any.whl.metadata (6.6 kB)',
#  'Requirement already satisfied: requests in /opt/anaconda3/envs/udagen/lib/python3.11/site-packages (from bertviz) (2.31.0)',
#  'Requirement already satisfied: regex in /opt/anaconda3/envs/udagen/lib/python3.11/site-packages (from bertviz) (2023.10.3)',
#  'Requirement already satisfied: sentencepiece in /opt/anaconda3/envs/udagen/lib/python3.11/site-packages (from bertviz) (0.1.99)',
#  'Requirement already satisfied: filelock in /opt/anaconda3/envs/udagen/lib/python3.11/site-packages (from torch>=1.0->bertviz) (3.13.1)',
#  'Requirement already satisfied: typing-extensions>=4.8.0 in /opt/anaconda3/envs/udagen/lib/python3.11/site-packages (from torch>=1.0->bertviz) (4.9.0)',
#  'Requirement already satisfied: sympy in /opt/anaconda3/envs/udagen/lib/python3.11/site-packages (from torch>=1.0->bertviz) (1.12)',
#  'Requirement already satisfied: networkx in /opt/anaconda3/envs/udagen/lib/python3.11/site-packages (from torch>=1.0->bertviz) (3.1)',
#  'Requirement already satisfied: jinja2 in /opt/anaconda3/envs/udagen/lib/python3.11/site-packages (from torch>=1.0->bertviz) (3.1.3)',
#  'Requirement already satisfied: fsspec in /opt/anaconda3/envs/udagen/lib/python3.11/site-packages (from torch>=1.0->bertviz) (2024.3.1)',
#  'Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /opt/anaconda3/envs/udagen/lib/python3.11/site-packages (from transformers>=2.0->bertviz) (0.22.2)',
#  'Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/envs/udagen/lib/python3.11/site-packages (from transformers>=2.0->bertviz) (1.26.4)',
#  'Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/udagen/lib/python3.11/site-packages (from transformers>=2.0->bertviz) (23.2)',
#  'Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/envs/udagen/lib/python3.11/site-packages (from transformers>=2.0->bertviz) (6.0.1)',
#  'Requirement already satisfied: tokenizers<0.19,>=0.14 in /opt/anaconda3/envs/udagen/lib/python3.11/site-packages (from transformers>=2.0->bertviz) (0.15.1)',
#  'Requirement already satisfied: safetensors>=0.4.1 in /opt/anaconda3/envs/udagen/lib/python3.11/site-packages (from transformers>=2.0->bertviz) (0.4.2)',
#  'Collecting botocore<1.35.0,>=1.34.117 (from boto3->bertviz)',
#  '  Downloading botocore-1.34.117-py3-none-any.whl.metadata (5.7 kB)',
#  'Collecting jmespath<2.0.0,>=0.7.1 (from boto3->bertviz)',
#  '  Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)',
#  'Collecting s3transfer<0.11.0,>=0.10.0 (from boto3->bertviz)',
#  '  Downloading s3transfer-0.10.1-py3-none-any.whl.metadata (1.7 kB)',
#  'Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/udagen/lib/python3.11/site-packages (from requests->bertviz) (2.0.4)',
#  'Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/udagen/lib/python3.11/site-packages (from requests->bertviz) (3.7)',
#  'Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/udagen/lib/python3.11/site-packages (from requests->bertviz) (2.1.0)',
#  'Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/udagen/lib/python3.11/site-packages (from requests->bertviz) (2024.2.2)',
#  'Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/anaconda3/envs/udagen/lib/python3.11/site-packages (from botocore<1.35.0,>=1.34.117->boto3->bertviz) (2.8.2)',
#  'Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/udagen/lib/python3.11/site-packages (from jinja2->torch>=1.0->bertviz) (2.1.3)',
#  'Requirement already satisfied: mpmath>=0.19 in /opt/anaconda3/envs/udagen/lib/python3.11/site-packages (from sympy->torch>=1.0->bertviz) (1.3.0)',
#  'Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/udagen/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.35.0,>=1.34.117->boto3->bertviz) (1.16.0)',
#  'Downloading bertviz-1.4.0-py3-none-any.whl (157 kB)',
#  '\x1b[?25l   \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b0.0/157.6 kB\x1b \x1b?\x1b eta \x1b-:--:--\x1b',
#  '\x1b[2K   \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b157.6/157.6 kB\x1b \x1b8.7 MB/s\x1b eta \x1b0:00:00\x1b',
#  '\x1b[?25hDownloading boto3-1.34.117-py3-none-any.whl (139 kB)',
#  '\x1b[?25l   \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b0.0/139.3 kB\x1b \x1b?\x1b eta \x1b-:--:--\x1b',
#  '\x1b[2K   \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b139.3/139.3 kB\x1b \x1b12.0 MB/s\x1b eta \x1b0:00:00\x1b',
#  '\x1b[?25hDownloading botocore-1.34.117-py3-none-any.whl (12.3 MB)',
#  '\x1b[?25l   \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b0.0/12.3 MB\x1b \x1b?\x1b eta \x1b-:--:--\x1b',
#  '\x1b[2K   \x1b━━━\x1b\x1b╸\x1b\x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b1.2/12.3 MB\x1b \x1b31.4 MB/s\x1b eta \x1b0:00:01\x1b',
#  '\x1b[2K   \x1b━━━━━━━\x1b\x1b╸\x1b\x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b2.4/12.3 MB\x1b \x1b30.8 MB/s\x1b eta \x1b0:00:01\x1b',
#  '\x1b[2K   \x1b━━━━━━━━━━━\x1b\x1b╸\x1b\x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b3.6/12.3 MB\x1b \x1b30.5 MB/s\x1b eta \x1b0:00:01\x1b',
#  '\x1b[2K   \x1b━━━━━━━━━━━━━━━\x1b\x1b╺\x1b\x1b━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b4.7/12.3 MB\x1b \x1b30.4 MB/s\x1b eta \x1b0:00:01\x1b',
#  '\x1b[2K   \x1b━━━━━━━━━━━━━━━━━━━\x1b\x1b╺\x1b\x1b━━━━━━━━━━━━━━━━━━━━\x1b \x1b5.9/12.3 MB\x1b \x1b30.2 MB/s\x1b eta \x1b0:00:01\x1b',
#  '\x1b[2K   \x1b━━━━━━━━━━━━━━━━━━━━━━\x1b\x1b╸\x1b\x1b━━━━━━━━━━━━━━━━━\x1b \x1b7.1/12.3 MB\x1b \x1b30.2 MB/s\x1b eta \x1b0:00:01\x1b',
#  '\x1b[2K   \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b\x1b╸\x1b\x1b━━━━━━━━━━━━━\x1b \x1b8.2/12.3 MB\x1b \x1b30.2 MB/s\x1b eta \x1b0:00:01\x1b',
#  '\x1b[2K   \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b\x1b╺\x1b\x1b━━━━━━━━━\x1b \x1b9.3/12.3 MB\x1b \x1b30.1 MB/s\x1b eta \x1b0:00:01\x1b',
#  '\x1b[2K   \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b\x1b╺\x1b\x1b━━━━━\x1b \x1b10.5/12.3 MB\x1b \x1b30.0 MB/s\x1b eta \x1b0:00:01\x1b',
#  '\x1b[2K   \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b\x1b╸\x1b\x1b━━\x1b \x1b11.6/12.3 MB\x1b \x1b30.0 MB/s\x1b eta \x1b0:00:01\x1b',
#  '\x1b[2K   \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b12.3/12.3 MB\x1b \x1b29.0 MB/s\x1b eta \x1b0:00:00\x1b',
#  '\x1b[?25hDownloading jmespath-1.0.1-py3-none-any.whl (20 kB)',
#  'Downloading s3transfer-0.10.1-py3-none-any.whl (82 kB)',
#  '\x1b[?25l   \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b0.0/82.2 kB\x1b \x1b?\x1b eta \x1b-:--:--\x1b',
#  '\x1b[2K   \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b82.2/82.2 kB\x1b \x1b10.4 MB/s\x1b eta \x1b0:00:00\x1b',
#  '\x1b[?25hInstalling collected packages: jmespath, botocore, s3transfer, boto3, bertviz',
#  'Successfully installed bertviz-1.4.0 boto3-1.34.117 botocore-1.34.117 jmespath-1.0.1 s3transfer-0.10.1']

# %%
from transformers import AutoModel, AutoTokenizer, utils

utils.logging.set_verbosity_error()  # Suppress standard warnings

tokenizer = AutoTokenizer.from_pretrained("gpt2")
model = AutoModel.from_pretrained("gpt2", output_attentions=True)

# %%
from bertviz import head_view, model_view

inputs = tokenizer.encode(
    "The doctor asked the nurse a question. She", return_tensors="pt"
)
outputs = model(inputs)
attention = outputs[-1]
tokens = tokenizer.convert_ids_to_tokens(inputs[0])

head_view(attention, tokens, layer=5, heads=[10])
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#
#         <div id="bertviz-063ac5ae565340edbd3ff0cc46c25417" style="font-family:'Helvetica Neue', Helvetica, Arial, sans-serif;">
#             <span style="user-select:none">
#                 Layer: <select id="layer"></select>
#
#             </span>
#             <div id='vis'></div>
#         </div>

# %%
model_view(attention, tokens)
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#
#         <div id="bertviz-ac9e815d3c634bbca73b393fd7582bff" style="font-family:'Helvetica Neue', Helvetica, Arial, sans-serif;">
#             <span style="user-select:none">
#
#             </span>
#             <div id='vis'></div>
#         </div>

# %%
inputs = tokenizer.encode(
    "The doctor asked the nurse a question. He", return_tensors="pt"
)
outputs = model(inputs)
attention = outputs[-1]
tokens = tokenizer.convert_ids_to_tokens(inputs[0])

head_view(attention, tokens, layer=5, heads=[10])

# %% [markdown]
# ## The teacher asked the inspector...
#
# A similar analysis on the following two sentences can be made:
#
# * "The teacher asked the inspector if the school was structurally sound. He"
# * "The teacher asked the inspector if the school was structurally sound. She"
#
# In this case, the attention mechanism shows "He" attending to both teacher and inspector more or less equally but "She" attends to "teacher" disproportionately.

# %%
inputs = tokenizer.encode(
    "The teacher asked the inspector if the school was structurally sound. He",
    return_tensors="pt",
)
outputs = model(inputs)
attention = outputs[-1]
tokens = tokenizer.convert_ids_to_tokens(inputs[0])

head_view(attention, tokens, layer=5, heads=[10])

# %%
inputs = tokenizer.encode(
    "The teacher asked the inspector if the school was structurally sound. She",
    return_tensors="pt",
)
outputs = model(inputs)
attention = outputs[-1]
tokens = tokenizer.convert_ids_to_tokens(inputs[0])

head_view(attention, tokens, layer=5, heads=[10])

# %% [markdown]
# Useful Links:
# * [BertViz Website](https://github.com/jessevig/bertviz)
# * [BertViz Paper](https://aclanthology.org/P19-3007.pdf)
# * [BertViz Colab Tutorial](https://colab.research.google.com/drive/1hXIQ77A4TYS4y3UthWF-Ci7V7vVUoxmQ?usp=sharing)
